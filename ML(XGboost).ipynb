# %%
import pandas as pd
dataset = pd.read_csv('Housing.csv')

# %%
dataset
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
print(dataset.shape)
# Out:
# (506, 15)

# %%
dataset[:5]
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
dataset = pd.concat([dataset['medv'],dataset.drop(['medv'], axis=1)],axis=1)
dataset[:1]
# Out:
#    medv  Unnamed: 0     crim    zn  indus  chas    nox     rm   age   dis  \
# 0  24.0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09
#
#    rad  tax  ptratio  black  lstat
# 0    1  296     15.3  396.9   4.98

# %%
from sklearn.model_selection import train_test_split
training_dataset, validation_dataset = train_test_split(dataset, test_size=0.1)

# %%
training_dataset.to_csv('training_dataset.csv', index=False, header=False)
validation_dataset.to_csv('validation_dataset.csv',index=False, header=False)

# %%
import sagemaker
sess = sagemaker.Session()
bucket = sess.default_bucket()

# %%
prefix = 'boston-housing'
training_data_path = sess.upload_data(
 path='training_dataset.csv',
 key_prefix=prefix + '/input/training')
validation_data_path = sess.upload_data(
 path='validation_dataset.csv',
 key_prefix=prefix + '/input/validation')
print(training_data_path)
print(validation_data_path)
# Out:
# s3://sagemaker-us-west-2-373913539787/boston-housing/input/training/training_dataset.csv
# s3://sagemaker-us-west-2-373913539787/boston-housing/input/validation/validation_dataset.csv

# %%
import boto3
from sagemaker import image_uris

# %%
region = boto3.Session().region_name
container = image_uris.retrieve('xgboost', region,
 version='latest')

# %%
from sagemaker.estimator import Estimator
xgb_estimator = Estimator(
 container,
 role=sagemaker.get_execution_role(),
 instance_count=1,
 instance_type='ml.m4.xlarge',
 output_path='s3://{}/{}/output'.format(bucket,
 prefix))

# %%
xgb_estimator.set_hyperparameters(
 objective='reg:linear',
 num_round=200,
 early_stopping_rounds=10)

# %%
training_data_channel = sagemaker.TrainingInput(
 s3_data=training_data_path,
 content_type='text/csv')

# %%
validation_data_channel = sagemaker.TrainingInput(
 s3_data=validation_data_path,
 content_type='text/csv')

# %%
xgb_estimator.fit({'train': training_data_channel,
 'validation': validation_data_channel})
# Out:
# 2021-04-08 17:45:36 Starting - Starting the training job...
# 2021-04-08 17:46:00 Starting - Launching requested ML instancesProfilerReport-1617903936: InProgress
# ......
# 2021-04-08 17:47:05 Starting - Preparing the instances for training.........
# 2021-04-08 17:48:25 Downloading - Downloading input data
# 2021-04-08 17:48:25 Training - Downloading the training image..Arguments: train
# [2021-04-08:17:48:46:INFO] Running standalone xgboost training.
# [2021-04-08:17:48:46:INFO] File size need to be processed in the node: 0.04mb. Available memory size in the node: 8431.5mb
# [2021-04-08:17:48:46:INFO] Determined delimiter of CSV input is ','
# [17:48:46] S3DistributionType set as FullyReplicated
# [17:48:46] 455x14 matrix with 6370 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-04-08:17:48:46:INFO] Determined delimiter of CSV input is ','
# [17:48:46] S3DistributionType set as FullyReplicated
# [17:48:46] 51x14 matrix with 714 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-rmse:17.2301#011validation-rmse:15.1681
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:12.398#011validation-rmse:10.8782
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:9.00809#011validation-rmse:8.05488
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-rmse:6.61997#011validation-rmse:6.09287
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-rmse:4.93555#011validation-rmse:4.80601
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:3.70628#011validation-rmse:3.94524
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:2.85773#011validation-rmse:3.4015
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-rmse:2.27112#011validation-rmse:3.0873
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-rmse:1.8438#011validation-rmse:2.90853
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:1.53148#011validation-rmse:2.83066
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:1.33201#011validation-rmse:2.77338
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-rmse:1.18757#011validation-rmse:2.7094
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-rmse:1.07546#011validation-rmse:2.69243
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-rmse:0.978485#011validation-rmse:2.65688
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:0.923749#011validation-rmse:2.65904
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-rmse:0.882164#011validation-rmse:2.65314
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:0.82964#011validation-rmse:2.62335
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-rmse:0.796618#011validation-rmse:2.62589
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-rmse:0.772042#011validation-rmse:2.61216
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-rmse:0.741844#011validation-rmse:2.59497
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-rmse:0.692658#011validation-rmse:2.58905
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-rmse:0.668674#011validation-rmse:2.59993
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-rmse:0.626303#011validation-rmse:2.59261
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-rmse:0.590518#011validation-rmse:2.59004
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-rmse:0.57941#011validation-rmse:2.57328
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-rmse:0.540065#011validation-rmse:2.56044
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-rmse:0.517663#011validation-rmse:2.56403
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-rmse:0.485729#011validation-rmse:2.55333
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-rmse:0.454106#011validation-rmse:2.54584
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-rmse:0.427508#011validation-rmse:2.56514
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-rmse:0.407497#011validation-rmse:2.5644
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-rmse:0.400528#011validation-rmse:2.56513
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-rmse:0.392696#011validation-rmse:2.56156
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-rmse:0.382609#011validation-rmse:2.56424
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-rmse:0.354535#011validation-rmse:2.56911
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-rmse:0.329713#011validation-rmse:2.5691
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-rmse:0.310139#011validation-rmse:2.55823
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-rmse:0.297727#011validation-rmse:2.56134
# [17:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-rmse:0.283558#011validation-rmse:2.55834
# Stopping. Best iteration:
# [28]#011train-rmse:0.454106#011validation-rmse:2.54584
#
#
# 2021-04-08 17:49:00 Uploading - Uploading generated training model
# 2021-04-08 17:49:00 Completed - Training job completed
# Training seconds: 50
# Billable seconds: 50

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())
endpoint_name = 'xgb-demo'+'-'+timestamp
xgb_predictor = xgb_estimator.deploy(
 endpoint_name=endpoint_name,
 initial_instance_count=1,
 instance_type='ml.t2.medium')
# Out:
# ---------------!

# %%
# test_sample = '0.00632,18.0,2.31,0,0.538,6.575,65.2,4.09,1,296,15.3,396.9,4.98'
test_samples = [
'0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,396.9,4.98',
'0.02731,0.00,7.070,0,0.4690,6.4210,78.90,4.9671,2,242.0,17.80,396.9,9.14']

# %%
xgb_predictor.CONTENT_TYPE = 'text/csv'
xgb_predictor.serializer = sagemaker.serializers.CSVSerializer()
xgb_predictor.deserializer = sagemaker.deserializers.CSVDeserializer()

# %%
response = xgb_predictor.predict(test_sample)

# %%
response
# Out:
# [['43.45135498046875']]

# %%
dataset[:2]
# Out:
#    medv  Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  \
# 0  24.0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900
# 1  21.6           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671
#
#    rad  tax  ptratio  black  lstat
# 0    1  296     15.3  396.9   4.98
# 1    2  242     17.8  396.9   9.14
